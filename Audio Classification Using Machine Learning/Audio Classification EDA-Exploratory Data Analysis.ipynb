# %%
# !pip install  --user librosa
# Out:
# Requirement already satisfied: librosa in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (0.10.0.post2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.57.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.0.5)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.40.1rc1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from pooch<1.7,>=1.0->librosa) (23.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.28.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aneesh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.12.7)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename=r"UrbanSound8K/UrbanSound8K/dog_bark.wav"

# %%
import librosa
print(librosa.__version__)
dir(librosa.display)
# Out:
# 0.10.0.post2
# ['AdaptiveWaveplot',
#  'Any',
#  'Callable',
#  'ChromaFJSFormatter',
#  'ChromaFormatter',
#  'ChromaSvaraFormatter',
#  'Collection',
#  'Deprecated',
#  'Dict',
#  'FJSFormatter',
#  'LogHzFormatter',
#  'NoteFormatter',
#  'Optional',
#  'ParameterError',
#  'SvaraFormatter',
#  'TYPE_CHECKING',
#  'TimeFormatter',
#  'TonnetzFormatter',
#  'Union',
#  '_AXIS_COMPAT',
#  '_FloatLike_co',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__check_axes',
#  '__coord_chroma',
#  '__coord_cqt_hz',
#  '__coord_fft_hz',
#  '__coord_fourier_tempo',
#  '__coord_mel_hz',
#  '__coord_n',
#  '__coord_tempo',
#  '__coord_time',
#  '__coord_vqt_hz',
#  '__decorate_axis',
#  '__doc__',
#  '__envelope',
#  '__file__',
#  '__loader__',
#  '__mesh_coords',
#  '__name__',
#  '__package__',
#  '__same_axes',
#  '__scale_axes',
#  '__set_current_image',
#  '__spec__',
#  '_chroma_ax_types',
#  '_cqt_ax_types',
#  '_freq_ax_types',
#  '_lag_ax_types',
#  '_misc_ax_types',
#  '_time_ax_types',
#  'annotations',
#  'cmap',
#  'core',
#  'lazy',
#  'matplotlib',
#  'mcm',
#  'mplaxes',
#  'mplticker',
#  'np',
#  'plt',
#  'product',
#  'rename_kw',
#  'specshow',
#  'util',
#  'warnings',
#  'waveshow']

# %%
import IPython.display as ipd
import librosa

from librosa.display import waveshow

# %%
plt.figure(figsize=(15,15))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
data
# Out:
# array([ 2.8747239e-04, -6.8418565e-05, -5.6744809e-04, ...,
#         1.5392607e-02,  1.8679928e-02,  2.3103174e-02], dtype=float32)

# %%
from scipy.io import wavfile as wav
wave_sample_rate,wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[  3,  23],
#        [ -8,  19],
#        [-37,  39],
#        ...,
#        [484, 871],
#        [506, 930],
#        [507, 962]], dtype=int16)

# %%
import pandas as pd
metadata=pd.read_csv(r"UrbanSound8K\UrbanSound8K\metadata\UrbanSound8K.csv")
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
